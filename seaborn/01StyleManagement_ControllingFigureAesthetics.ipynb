# %%
# %matplotlib inline
import numpy as np
import matplotlib as mpl
import matplotlib.pylab as plt
np.random.seed(sum(map(ord, 'aesthetics')))

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)#100 data from 0 to 14
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i*.5)*(7-i)*flip)

# %%
# matplotlib
sinplot()

# %%
import seaborn as sns
# Note that in versions of seaborn prior to 0.8, 
# set() was called on import. On later versions, 
# it must be explicitly invoked
sns.set()
sinplot()

# %% [markdown]
# ---
# # Seaborn figure styles

# %% [markdown]
# There are five preset seaborn themes:
# - ***darkgrid***
# - ***whitegrid***
# - ***dark***
# - ***white***
# - ***ticks***
#
# They are each suited to different applications and personal preferences. **The default theme is darkgrid**. As mentioned above, the grid helps the plot serve as a lookup table for quantitative information, and the white-on grey helps to keep the grid from competing with lines that represent data. The whitegrid theme is similar, but it is better suited to plots with heavy data elements:

# %%
sns.set_style("whitegrid")
data = np.random.normal(size=(20, 6)) + np.arange(6)/2
sns.boxplot(data=data)

# %%
sns.set_style('dark')
sinplot()

# %%
sns.set_style('white')
sinplot()

# %% [markdown]
# *sometimes you might want to give a little extra structure to the plots, which is where ticks come in handy*

# %%
sns.set_style("ticks")
sinplot()

# %% [markdown]
# # Removing axes spines
# Both the *white* and *ticks* styles can benefit from removeing the **top** and **right** axes spines, which are not need.
# Call function **despine()** to remove them.

# %%
sns.set_style("ticks")
sinplot()
sns.despine()

# %% [markdown]
# Some plots benefit from offsetting the spines away from the data, which can also be done when calling **despine()**.
# When the ticks don’t cover the whole range of the axis, the **trim** parameter will limit the range of the surviving spines.

# %%
f, ax = plt.subplots()
sns.violinplot(data=data)
sns.despine(offset=10, trim=True);

# %% [markdown]
# 使用**despine()**函数去除坐标轴

# %%
sns.set_style('whitegrid')
sns.boxplot(data=data, palette='deep')
sns.despine(left=True)

# %% [markdown]
# # Temporarily setting figure style
# 使用**axes_style()**临时设定plot的参数

# %%
with sns.axes_style('darkgrid'):
    plt.subplot(211)
    sinplot()
plt.subplot(212)
sinplot(-1)

# %% [markdown]
# # Overriding elements of the seaborn styles
# **axex_style()**函数可以查看seaborn支持的style属性
# **set_style(rc=dict)**函数可以使用字典设置style属性

# %%
sns.axes_style()
# Out:
# {'axes.axisbelow': True,
#  'axes.edgecolor': '.8',
#  'axes.facecolor': 'white',
#  'axes.grid': True,
#  'axes.labelcolor': '.15',
#  'axes.linewidth': 1.0,
#  'figure.facecolor': 'white',
#  'font.family': [u'sans-serif'],
#  'font.sans-serif': [u'Arial',
#   u'Liberation Sans',
#   u'Bitstream Vera Sans',
#   u'sans-serif'],
#  'grid.color': '.8',
#  'grid.linestyle': u'-',
#  'image.cmap': u'Greys',
#  'legend.frameon': False,
#  'legend.numpoints': 1,
#  'legend.scatterpoints': 1,
#  'lines.solid_capstyle': u'round',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'xtick.direction': u'out',
#  'xtick.major.size': 0.0,
#  'xtick.minor.size': 0.0,
#  'ytick.color': '.15',
#  'ytick.direction': u'out',
#  'ytick.major.size': 0.0,
#  'ytick.minor.size': 0.0}

# %%
sns.set_style("darkgrid",rc={'axes.facecolor':'.5'})
sinplot()

# %% [markdown]
# # Scaling plot elements
# **set()**函数可以初始化缺省参数
# 四个预先设置的上下文context参数:**paper**,**notebook**,**talk**,**poster**
# 缺省值为**notebook**

# %%
sns.set()
sns.set_context('paper')
sinplot()

# %%
sns.set()
sns.set_context('talk')
sinplot()

# %%
sns.set()
sns.set_context('poster')
sinplot()

# %% [markdown]
# **set_context()**函数可以同时设定style参数

# %%
sns.set_context("notebook", font_scale=2.0, rc={"lines.linewidth":2.5})
sinplot()
